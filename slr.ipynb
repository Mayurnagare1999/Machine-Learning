# %%
import pandas as pd
import numpy as np
from io import StringIO
import matplotlib.pyplot as plt
from sklearn import linear_model
import openpyxl

# %%
data = """area,price
142,2316
200,5623
242,6424
292,8122
320,9432
"""

# %%
data_io = StringIO(data)

# %%
df = pd.read_excel("slr.xlsx")
df
# Out:
#    area  price
# 0   142   4232
# 1   200   5200
# 2   252   7300
# 3   300   9800
# 4   352  14000
# 5   420  16899

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   area    6 non-null      int64
#  1   price   6 non-null      int64
# dtypes: int64(2)
# memory usage: 228.0 bytes

# %%
# %matplotlib inline
plt.scatter(df['area'],df['price'],color = 'red',marker = '+')
plt.plot(df.area,reg.predict(df[['area']]),color='blue')
plt.xlabel('Area(sqr ft)')
plt.ylabel('Price(usd)')
plt.show()

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[2342]])
# Out:
# c:\Users\Mayur\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([109995.42638415])

# %%
reg.coef_   ### coeffiecient is m or slope
# Out:
# array([48.64698517])

# %%
reg.intercept_   ### this showls the y inntercept (b)
# Out:
# np.float64(-3935.8128819629164)

# %%
# m*x+c
48.64698517*2342+(-3935.8128819629164)
# Out:
# 109995.42638617709

# %%
### now we want to predict the data another set of value
df_n = pd.read_csv('slr_test.csv.csv')
df_n
# Out:
#    area
# 0   234
# 1   452
# 2   241
# 3  1241
# 4   422
# 5   231
# 6  3124
# 7   242

# %%
### preditct the values of the dataframe

m = reg.predict(df_n)

# %%
df_n['prices']=m ## assigned into dataframe

# %%
df_n  ## we can see the
# Out:
#    area         prices
# 0   234    7447.581648
# 1   452   18052.624414
# 2   241    7788.110544
# 3  1241   56435.095713
# 4   422   16593.214859
# 5   231    7301.640692
# 6  3124  148037.368786
# 7   242    7836.757529

# %%
df_n.to_csv('slr_prediction.csv')
